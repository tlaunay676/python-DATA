# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données (la table fusionnée)
file_path = 'WHO_SDG_GPW_SDG3_fusionne_secure.csv'  # ou votre fichier sécurisé
df = pd.read_csv(file_path)

# --- CONFIGURATION DES VARIABLES ---
# Remplacez ces noms par les colonnes exactes de votre fichier
colonne_Y = 'Espérance de vie en bonne santé totale'  # La variable à prédire (ex: Espérance de vie)
colonne_D = 'Dépenses publiques santé'  # La variable explicative (ex: PIB, Dépenses santé)

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage des données
# La régression ne supporte pas les valeurs manquantes (NaN)
data_reg = df[[colonne_Y, colonne_D]].dropna()

# Vérification qu'il reste des données
if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Préparation des variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    
    # AJOUT DE LA CONSTANTE (C'est votre "1" dans X=(1,D))
    # Sans cela, la droite passerait forcément par 0 (l'origine)
    X = sm.add_constant(D) 

    # 4. Ajustement du modèle (OLS = Ordinary Least Squares)
    model = sm.OLS(Y, X)
    results = model.fit()

    # 5. Afficher le rapport statistique complet
    print(results.summary())

    # --- VISUALISATION ---
    plt.figure(figsize=(10, 6))
    
    # Nuage de points (Données réelles)
    plt.scatter(data_reg[colonne_D], data_reg[colonne_Y], alpha=0.5, label='Données observées')
    
    # Droite de régression (Prédictions)
    # On utilise les paramètres du modèle pour tracer la ligne
    plt.plot(data_reg[colonne_D], results.predict(X), color='red', linewidth=2, label='Droite de régression')
    
    plt.title(f'Régression Linéaire : {colonne_Y} vs {colonne_D}')
    plt.xlabel(colonne_D)
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Sauvegarder le graphique
    plt.savefig('resultat_regression.png')
    print("\n✓ Graphique sauvegardé sous 'resultat_regression.png'")
    # plt.show() # Décommentez si vous exécutez cela dans un notebook Jupyter local
# Out:
# Régression de 'Espérance de vie en bonne santé totale' sur 'Dépenses publiques santé'
#                                       OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie en bonne santé totale   R-squared:                       0.348
# Model:                                                OLS   Adj. R-squared:                  0.345
# Method:                                     Least Squares   F-statistic:                     95.69
# Date:                                    Sun, 07 Dec 2025   Prob (F-statistic):           2.25e-18
# Time:                                            12:40:47   Log-Likelihood:                -542.94
# No. Observations:                                     181   AIC:                             1090.
# Df Residuals:                                         179   BIC:                             1096.
# Df Model:                                               1
# Covariance Type:                                nonrobust
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données (la table fusionnée)
file_path = 'WHO_SDG_GPW_SDG3_fusionne_secure.csv'  # ou votre fichier sécurisé
df = pd.read_csv(file_path)

# --- CONFIGURATION DES VARIABLES ---
# Remplacez ces noms par les colonnes exactes de votre fichier
colonne_Y = 'Espérance de vie totale'  # La variable à prédire (ex: Espérance de vie)
colonne_D = 'Dépenses publiques santé'  # La variable explicative (ex: PIB, Dépenses santé)

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage des données
# La régression ne supporte pas les valeurs manquantes (NaN)
data_reg = df[[colonne_Y, colonne_D]].dropna()

# Vérification qu'il reste des données
if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Préparation des variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    
    # AJOUT DE LA CONSTANTE (C'est votre "1" dans X=(1,D))
    # Sans cela, la droite passerait forcément par 0 (l'origine)
    X = sm.add_constant(D) 

    # 4. Ajustement du modèle (OLS = Ordinary Least Squares)
    model = sm.OLS(Y, X)
    results = model.fit()

    # 5. Afficher le rapport statistique complet
    print(results.summary())

    # --- VISUALISATION ---
    plt.figure(figsize=(10, 6))
    
    # Nuage de points (Données réelles)
    plt.scatter(data_reg[colonne_D], data_reg[colonne_Y], alpha=0.5, label='Données observées')
    
    # Droite de régression (Prédictions)
    # On utilise les paramètres du modèle pour tracer la ligne
    plt.plot(data_reg[colonne_D], results.predict(X), color='red', linewidth=2, label='Droite de régression')
    
    plt.title(f'Régression Linéaire : {colonne_Y} vs {colonne_D}')
    plt.xlabel(colonne_D)
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Sauvegarder le graphique
    plt.savefig('resultat_regression.png')
    print("\n✓ Graphique sauvegardé sous 'resultat_regression.png'")
    # plt.show() # Décommentez si vous exécutez cela dans un notebook Jupyter local
# Out:
# Régression de 'Espérance de vie totale' sur 'Dépenses publiques santé'
#                                OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie totale   R-squared:                       0.363
# Model:                                 OLS   Adj. R-squared:                  0.360
# Method:                      Least Squares   F-statistic:                     102.1
# Date:                     Sat, 06 Dec 2025   Prob (F-statistic):           2.82e-19
# Time:                             12:39:30   Log-Likelihood:                -572.51
# No. Observations:                      181   AIC:                             1149.
# Df Residuals:                          179   BIC:                             1155.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données (la table fusionnée)
file_path = 'Table_complète.csv'  # ou votre fichier sécurisé
df = pd.read_csv(file_path)

# --- CONFIGURATION DES VARIABLES ---
# Remplacez ces noms par les colonnes exactes de votre fichier
colonne_Y = 'Anxiety_disorders'  # La variable à prédire (ex: Espérance de vie)
colonne_D = '2024'  # La variable explicative (ex: PIB, Dépenses santé)

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage des données
# La régression ne supporte pas les valeurs manquantes (NaN)
data_reg = df[[colonne_Y, colonne_D]].dropna()

# Vérification qu'il reste des données
if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Préparation des variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    
    # AJOUT DE LA CONSTANTE (C'est votre "1" dans X=(1,D))
    # Sans cela, la droite passerait forcément par 0 (l'origine)
    X = sm.add_constant(D) 

    # 4. Ajustement du modèle (OLS = Ordinary Least Squares)
    model = sm.OLS(Y, X)
    results = model.fit()

    # 5. Afficher le rapport statistique complet
    print(results.summary())

    # --- VISUALISATION ---
    plt.figure(figsize=(10, 6))
    
    # Nuage de points (Données réelles)
    plt.scatter(data_reg[colonne_D], data_reg[colonne_Y], alpha=0.5, label='Données observées')
    
    # Droite de régression (Prédictions)
    # On utilise les paramètres du modèle pour tracer la ligne
    plt.plot(data_reg[colonne_D], results.predict(X), color='red', linewidth=2, label='Droite de régression')
    
    plt.title(f'Régression Linéaire : {colonne_Y} vs {colonne_D}')
    plt.xlabel(colonne_D)
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Sauvegarder le graphique
    plt.savefig('resultat_regression.png')
    print("\n✓ Graphique sauvegardé sous 'resultat_regression.png'")
    # plt.show() # Décommentez si vous exécutez cela dans un notebook Jupyter local
# Out:
# Régression de 'Anxiety_disorders' sur '2024'
#                             OLS Regression Results
# ...
# Dep. Variable:      Anxiety_disorders   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     20.06
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):           1.35e-05
# Time:                        11:42:44   Log-Likelihood:                -1197.2
# No. Observations:                 176   AIC:                             2398.
# Df Residuals:                     174   BIC:                             2405.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        593.8358     20.724     28.654      0.000     552.932     634.739
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données (la table fusionnée)
file_path = 'Table_complète.csv'  # ou votre fichier sécurisé
df = pd.read_csv(file_path)

# --- CONFIGURATION DES VARIABLES ---
# Remplacez ces noms par les colonnes exactes de votre fichier
colonne_Y = 'Bipolar_disorder'  # La variable à prédire (ex: Espérance de vie)
colonne_D = '2021'  # La variable explicative (ex: PIB, Dépenses santé)

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage des données
# La régression ne supporte pas les valeurs manquantes (NaN)
data_reg = df[[colonne_Y, colonne_D]].dropna()

# Vérification qu'il reste des données
if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Préparation des variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    
    # AJOUT DE LA CONSTANTE (C'est votre "1" dans X=(1,D))
    # Sans cela, la droite passerait forcément par 0 (l'origine)
    X = sm.add_constant(D) 

    # 4. Ajustement du modèle (OLS = Ordinary Least Squares)
    model = sm.OLS(Y, X)
    results = model.fit()

    # 5. Afficher le rapport statistique complet
    print(results.summary())

    # --- VISUALISATION ---
    plt.figure(figsize=(10, 6))
    
    # Nuage de points (Données réelles)
    plt.scatter(data_reg[colonne_D], data_reg[colonne_Y], alpha=0.5, label='Données observées')
    
    # Droite de régression (Prédictions)
    # On utilise les paramètres du modèle pour tracer la ligne
    plt.plot(data_reg[colonne_D], results.predict(X), color='red', linewidth=2, label='Droite de régression')
    
    plt.title(f'Régression Linéaire : {colonne_Y} vs {colonne_D}')
    plt.xlabel(colonne_D)
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Sauvegarder le graphique
    plt.savefig('resultat_regression.png')
    print("\n✓ Graphique sauvegardé sous 'resultat_regression.png'")
    # plt.show() # Décommentez si vous exécutez cela dans un notebook Jupyter local
# Out:
# Régression de 'Bipolar_disorder' sur '2021'
#                             OLS Regression Results
# ...
# Dep. Variable:       Bipolar_disorder   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     17.45
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):           4.55e-05
# Time:                        16:48:20   Log-Likelihood:                -898.06
# No. Observations:                 187   AIC:                             1800.
# Df Residuals:                     185   BIC:                             1807.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        108.7942      2.564     42.431      0.000     103.736     113.853
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_complète.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Espérance de vie en bonne santé totale'
colonne_D = '2021'   # PIB 2019

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2021')
    plt.xlabel('PIB par habitant (2021)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Espérance de vie en bonne santé totale' sur '2021'
#                                       OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie en bonne santé totale   R-squared:                       0.437
# Model:                                                OLS   Adj. R-squared:                  0.434
# Method:                                     Least Squares   F-statistic:                     136.5
# Date:                                    Fri, 12 Dec 2025   Prob (F-statistic):           1.03e-23
# Time:                                            09:05:56   Log-Likelihood:                -520.23
# No. Observations:                                     178   AIC:                             1044.
# Df Residuals:                                         176   BIC:                             1051.
# Df Model:                                               1
# Covariance Type:                                nonrobust
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données (la table fusionnée)
file_path = 'Table_complète.csv'  # ou votre fichier sécurisé
df = pd.read_csv(file_path)

# --- CONFIGURATION DES VARIABLES ---
# Remplacez ces noms par les colonnes exactes de votre fichier
colonne_Y = 'Mental_disorders'  # La variable à prédire (ex: Espérance de vie)
colonne_D = '2024'  # La variable explicative (ex: PIB, Dépenses santé)

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage des données
# La régression ne supporte pas les valeurs manquantes (NaN)
data_reg = df[[colonne_Y, colonne_D]].dropna()

# Vérification qu'il reste des données
if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Préparation des variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    
    # AJOUT DE LA CONSTANTE (C'est votre "1" dans X=(1,D))
    # Sans cela, la droite passerait forcément par 0 (l'origine)
    X = sm.add_constant(D) 

    # 4. Ajustement du modèle (OLS = Ordinary Least Squares)
    model = sm.OLS(Y, X)
    results = model.fit()

    # 5. Afficher le rapport statistique complet
    print(results.summary())

    # --- VISUALISATION ---
    plt.figure(figsize=(10, 6))
    
    # Nuage de points (Données réelles)
    plt.scatter(data_reg[colonne_D], data_reg[colonne_Y], alpha=0.5, label='Données observées')
    
    # Droite de régression (Prédictions)
    # On utilise les paramètres du modèle pour tracer la ligne
    plt.plot(data_reg[colonne_D], results.predict(X), color='red', linewidth=2, label='Droite de régression')
    
    plt.title(f'Régression Linéaire : {colonne_Y} vs {colonne_D}')
    plt.xlabel(colonne_D)
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Sauvegarder le graphique
    plt.savefig('resultat_regression.png')
    print("\n✓ Graphique sauvegardé sous 'resultat_regression.png'")
    # plt.show() # Décommentez si vous exécutez cela dans un notebook Jupyter local
# Out:
# Régression de 'Mental_disorders' sur '2024'
#                             OLS Regression Results
# ...
# Dep. Variable:       Mental_disorders   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     36.49
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):           9.08e-09
# Time:                        11:45:27   Log-Likelihood:                -1273.5
# No. Observations:                 176   AIC:                             2551.
# Df Residuals:                     174   BIC:                             2557.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1959.7200     31.978     61.283      0.000    1896.605    2022.835
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données (la table fusionnée)
file_path = 'Table_complète.csv'  # ou votre fichier sécurisé
df = pd.read_csv(file_path)

# --- CONFIGURATION DES VARIABLES ---
# Remplacez ces noms par les colonnes exactes de votre fichier
colonne_Y = 'Eating_disorders'  # La variable à prédire (ex: Espérance de vie)
colonne_D = '2024'  # La variable explicative (ex: PIB, Dépenses santé)

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage des données
# La régression ne supporte pas les valeurs manquantes (NaN)
data_reg = df[[colonne_Y, colonne_D]].dropna()

# Vérification qu'il reste des données
if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Préparation des variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    
    # AJOUT DE LA CONSTANTE (C'est votre "1" dans X=(1,D))
    # Sans cela, la droite passerait forcément par 0 (l'origine)
    X = sm.add_constant(D) 

    # 4. Ajustement du modèle (OLS = Ordinary Least Squares)
    model = sm.OLS(Y, X)
    results = model.fit()

    # 5. Afficher le rapport statistique complet
    print(results.summary())

    # --- VISUALISATION ---
    plt.figure(figsize=(10, 6))
    
    # Nuage de points (Données réelles)
    plt.scatter(data_reg[colonne_D], data_reg[colonne_Y], alpha=0.5, label='Données observées')
    
    # Droite de régression (Prédictions)
    # On utilise les paramètres du modèle pour tracer la ligne
    plt.plot(data_reg[colonne_D], results.predict(X), color='red', linewidth=2, label='Droite de régression')
    
    plt.title(f'Régression Linéaire : {colonne_Y} vs {colonne_D}')
    plt.xlabel(colonne_D)
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Sauvegarder le graphique
    plt.savefig('resultat_regression.png')
    print("\n✓ Graphique sauvegardé sous 'resultat_regression.png'")
    # plt.show() # Décommentez si vous exécutez cela dans un notebook Jupyter local
# Out:
# Régression de 'Eating_disorders' sur '2024'
#                             OLS Regression Results
# ...
# Dep. Variable:       Eating_disorders   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     272.0
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):           2.11e-37
# Time:                        11:47:46   Log-Likelihood:                -779.74
# No. Observations:                 176   AIC:                             1563.
# Df Residuals:                     174   BIC:                             1570.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.5530      1.934     19.933      0.000      34.736      42.370
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_complète.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Eating_disorders'
colonne_D = '2024'   # PIB 2019

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Eating_disorders' sur '2024'
#                             OLS Regression Results
# ...
# Dep. Variable:       Eating_disorders   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     272.0
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):           2.11e-37
# Time:                        16:03:05   Log-Likelihood:                -779.74
# No. Observations:                 176   AIC:                             1563.
# Df Residuals:                     174   BIC:                             1570.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.5530      1.934     19.933      0.000      34.736      42.370
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_complète.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Attention_deficit_hyperactivity_disorder'
colonne_D = '2024'   # PIB 2024

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Attention_deficit_hyperactivity_disorder' sur '2024'
#                                        OLS Regression Results
# ...
# Dep. Variable:     Attention_deficit_hyperactivity_disorder   R-squared:                       0.040
# Model:                                                  OLS   Adj. R-squared:                  0.034
# Method:                                       Least Squares   F-statistic:                     7.240
# Date:                                      Tue, 09 Dec 2025   Prob (F-statistic):            0.00783
# Time:                                              16:09:59   Log-Likelihood:                -808.06
# No. Observations:                                       176   AIC:                             1620.
# Df Residuals:                                           174   BIC:                             1626.
# Df Model:                                                 1
# Covariance Type:                                  nonrobust
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_complète.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Conduct_disorder'
colonne_D = '2024'   # PIB 2024

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Conduct_disorder' sur '2024'
#                             OLS Regression Results
# ...
# Dep. Variable:       Conduct_disorder   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     8.859
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):            0.00333
# Time:                        16:11:28   Log-Likelihood:                -602.83
# No. Observations:                 176   AIC:                             1210.
# Df Residuals:                     174   BIC:                             1216.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         65.4265      0.708     92.431      0.000      64.029      66.824
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_complète.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Schizophrenia'
colonne_D = '2024'   # PIB 2024

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Schizophrenia' sur '2024'
#                             OLS Regression Results
# ...
# Dep. Variable:          Schizophrenia   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.833
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):              0.178
# Time:                        16:14:56   Log-Likelihood:                -792.34
# No. Observations:                 176   AIC:                             1589.
# Df Residuals:                     174   BIC:                             1595.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        187.8475      2.078     90.414      0.000     183.747     191.948
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_complète.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Idiopathic_developmental_intellectual_disability'
colonne_D = '2024'   # PIB 2024

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Idiopathic_developmental_intellectual_disability' sur '2024'
#                                            OLS Regression Results
# ...
# Dep. Variable:     Idiopathic_developmental_intellectual_disability   R-squared:                       0.000
# Model:                                                          OLS   Adj. R-squared:                 -0.006
# Method:                                               Least Squares   F-statistic:                  0.007146
# Date:                                              Tue, 09 Dec 2025   Prob (F-statistic):              0.933
# Time:                                                      16:44:40   Log-Likelihood:                -742.95
# No. Observations:                                               176   AIC:                             1490.
# Df Residuals:                                                   174   BIC:                             1496.
# Df Model:                                                         1
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_fusion_OMS_PIB.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Taux de suicides'
colonne_D = '2021'   # PIB 2024

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Taux de suicides' sur '2021'
#                             OLS Regression Results
# ...
# Dep. Variable:       Taux de suicides   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     6.524
# Date:                Tue, 09 Dec 2025   Prob (F-statistic):             0.0115
# Time:                        16:39:37   Log-Likelihood:                -569.87
# No. Observations:                 178   AIC:                             1144.
# Df Residuals:                     176   BIC:                             1150.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.7614      0.546     14.203      0.000       6.683       8.840
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Charger les données
file_path = 'Table_fusion_OMS_PIB.csv'
df = pd.read_csv(file_path)

# Variables
colonne_Y = 'Dépenses publiques santé'
colonne_D = '2021'   # PIB 2021

print(f"Régression de '{colonne_Y}' sur '{colonne_D}'")

# 2. Nettoyage
data_reg = df[[colonne_Y, colonne_D]].dropna()

if len(data_reg) == 0:
    print("Erreur : Plus aucune donnée après suppression des valeurs manquantes.")
else:
    # 3. Variables
    Y = data_reg[colonne_Y]
    D = data_reg[colonne_D]
    X = sm.add_constant(D)

    # 4. Régression
    model = sm.OLS(Y, X)
    results = model.fit()

    print(results.summary())

    # 5. TRI POUR DROITE PROPRE
    data_reg_sorted = data_reg.sort_values(by=colonne_D)
    X_sorted = sm.add_constant(data_reg_sorted[colonne_D])

    # 6. GRAPHIQUE
    plt.figure(figsize=(10, 6))

    plt.scatter(
        data_reg[colonne_D],
        data_reg[colonne_Y],
        alpha=0.5,
        label='Données observées'
    )

    plt.plot(
        data_reg_sorted[colonne_D],
        results.predict(X_sorted),
        linewidth=2,
        label='Droite de régression'
    )

    plt.title(f'Régression Linéaire : {colonne_Y} vs PIB 2019')
    plt.xlabel('PIB par habitant (2019)')
    plt.ylabel(colonne_Y)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Régression de 'Dépenses publiques santé' sur '2021'
#                                OLS Regression Results
# ...
# Dep. Variable:     Dépenses publiques santé   R-squared:                       0.194
# Model:                                  OLS   Adj. R-squared:                  0.190
# Method:                       Least Squares   F-statistic:                     44.18
# Date:                      Tue, 09 Dec 2025   Prob (F-statistic):           3.33e-10
# Time:                              16:41:57   Log-Likelihood:                -554.55
# No. Observations:                       185   AIC:                             1113.
# Df Residuals:                           183   BIC:                             1120.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#code régression linéaire simple avec Y=a+b*log(X)
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. CHARGEMENT DES DONNÉES ---
# Remplace 'chemin/vers/ton_fichier.csv' par le nom de ton fichier
# Si le fichier est dans le même dossier que ton script, mets juste 'nom_du_fichier.csv'
df = pd.read_csv('Table_complète.csv')

# Affiche les 5 premières lignes pour vérifier que tout est chargé correctement
print(df.head())

# --- 2. PRÉPARATION DES VARIABLES ---
# Remplace 'PIB' et 'Esperance_Vie' par les vrais noms de tes colonnes dans le CSV
# Exemple : si ta colonne s'appelle 'gdp_capita', écris : df['gdp_capita']

# Création de la variable D = log(PIB)
# On utilise np.log() qui est le logarithme népérien (naturel)
df['log_PIB'] = np.log(df['2021'])

# Définition de Y (variable expliquée) et X (variable explicative)
Y = df['Espérance de vie totale']
X = df['log_PIB']

# --- 3. RÉGRESSION LINÉAIRE ---
# Ajout de la constante pour avoir l'intercept (le C dans ton équation)
X_with_const = sm.add_constant(X)

# Création du modèle et ajustement (Fit)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

# --- 4. RÉSULTATS ---
print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Esperance_Vie'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Espérance de vie')
plt.legend()
plt.show()
# Out:
#          LOCATION  Anxiety_disorders  \
# 0     Afghanistan         622.102262
# 1         Albania         622.055601
# 2         Algeria         509.066068
# 3  American Samoa         497.372847
# 4         Andorra         991.200150
#
#    Attention_deficit_hyperactivity_disorder  Autism_spectrum_disorders  \
# 0                                 46.341833                 112.274411
# 1                                 24.743526                 122.889374
# 2                                 46.710674                 140.163061
# 3                                 37.585138                 114.126516
# 4                                 49.797228                 181.291698
#
#    Bipolar_disorder  Conduct_disorder  Depressive_disorders  Eating_disorders  \
# 0        131.845886         53.246743            928.523871         29.884592
# 1        100.829389         68.846147            403.288547         41.508016
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2021', 'Espérance de vie totale'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2021'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2021'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Espérance de vie totale'])

# 4. Définition des variables finales
Y = df['Espérance de vie totale']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Espérance de vie totale'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Espérance de vie')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 178
#                                OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie totale   R-squared:                       0.690
# Model:                                 OLS   Adj. R-squared:                  0.689
# Method:                      Least Squares   F-statistic:                     392.4
# Date:                     Fri, 12 Dec 2025   Prob (F-statistic):           1.13e-46
# Time:                             09:28:50   Log-Likelihood:                -498.56
# No. Observations:                      178   AIC:                             1001.
# Df Residuals:                          176   BIC:                             1007.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2021', 'Espérance de vie en bonne santé totale'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2021'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2021'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Espérance de vie en bonne santé totale'])

# 4. Définition des variables finales
Y = df['Espérance de vie en bonne santé totale']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Espérance de vie en bonne santé totale'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Espérance de vie en bonne santé')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 178
#                                       OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie en bonne santé totale   R-squared:                       0.673
# Model:                                                OLS   Adj. R-squared:                  0.671
# Method:                                     Least Squares   F-statistic:                     361.7
# Date:                                    Fri, 12 Dec 2025   Prob (F-statistic):           1.52e-44
# Time:                                            09:29:11   Log-Likelihood:                -471.94
# No. Observations:                                     178   AIC:                             947.9
# Df Residuals:                                         176   BIC:                             954.2
# Df Model:                                               1
# Covariance Type:                                nonrobust
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2023', 'Taux mortalité brute'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2023'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2023'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Taux mortalité brute'])

# 4. Définition des variables finales
Y = df['Taux mortalité brute']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Taux mortalité brute'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Taux de mortalité néonatale')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 184
#                              OLS Regression Results
# ...
# Dep. Variable:     Taux mortalité brute   R-squared:                       0.631
# Model:                              OLS   Adj. R-squared:                  0.629
# Method:                   Least Squares   F-statistic:                     311.8
# Date:                  Fri, 12 Dec 2025   Prob (F-statistic):           2.66e-41
# Time:                          09:41:22   Log-Likelihood:                -586.47
# No. Observations:                   184   AIC:                             1177.
# Df Residuals:                       182   BIC:                             1183.
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2023', 'Taux de mortalité maternelle'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2023'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2023'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Taux de mortalité maternelle'])

# 4. Définition des variables finales
Y = df['Taux de mortalité maternelle']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Taux de mortalité maternelle'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Taux de mortalité maternelle')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 185
#                                  OLS Regression Results
# ...
# Dep. Variable:     Taux de mortalité maternelle   R-squared:                       0.465
# Model:                                      OLS   Adj. R-squared:                  0.462
# Method:                           Least Squares   F-statistic:                     158.9
# Date:                          Fri, 12 Dec 2025   Prob (F-statistic):           1.26e-26
# Time:                                  09:52:16   Log-Likelihood:                -1146.0
# No. Observations:                           185   AIC:                             2296.
# Df Residuals:                               183   BIC:                             2302.
# Df Model:                                     1
# Covariance Type:                      nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2023', 'Médecins pour 10k habitants'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2023'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2023'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Médecins pour 10k habitants'])

# 4. Définition des variables finales
Y = df['Médecins pour 10k habitants']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Médecins pour 10k habitants'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Nombre de médecins pour 10k habitants')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 176
#                                  OLS Regression Results
# ...
# Dep. Variable:     Médecins pour 10k habitants   R-squared:                       0.406
# Model:                                     OLS   Adj. R-squared:                  0.403
# Method:                          Least Squares   F-statistic:                     119.0
# Date:                         Fri, 12 Dec 2025   Prob (F-statistic):           1.93e-21
# Time:                                 10:05:04   Log-Likelihood:                -444.39
# No. Observations:                          176   AIC:                             892.8
# Df Residuals:                              174   BIC:                             899.1
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2024', 'Capacité réponse sanitaire'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2024'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2024'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Capacité réponse sanitaire'])

# 4. Définition des variables finales
Y = df['Capacité réponse sanitaire']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Capacité réponse sanitaire'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Moyenne des 15 scores relatifs aux capacités fondamentales du Règlement sanitaire international')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 174
#                                 OLS Regression Results
# ...
# Dep. Variable:     Capacité réponse sanitaire   R-squared:                       0.423
# Model:                                    OLS   Adj. R-squared:                  0.420
# Method:                         Least Squares   F-statistic:                     126.1
# Date:                        Fri, 12 Dec 2025   Prob (F-statistic):           2.65e-22
# Time:                                10:30:25   Log-Likelihood:                -696.58
# No. Observations:                         174   AIC:                             1397.
# Df Residuals:                             172   BIC:                             1403.
# Df Model:                                   1
# Covariance Type:                    nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2022', 'Dépenses publiques santé'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2022'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2022'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Dépenses publiques santé'])

# 4. Définition des variables finales
Y = df['Dépenses publiques santé']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Dépenses publiques santé'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Part des dépenses de santé dans les dépenses publiques(%)')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 185
#                                OLS Regression Results
# ...
# Dep. Variable:     Dépenses publiques santé   R-squared:                       0.402
# Model:                                  OLS   Adj. R-squared:                  0.399
# Method:                       Least Squares   F-statistic:                     123.1
# Date:                      Fri, 12 Dec 2025   Prob (F-statistic):           3.30e-22
# Time:                              10:33:27   Log-Likelihood:                -526.96
# No. Observations:                       185   AIC:                             1058.
# Df Residuals:                           183   BIC:                             1064.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2021', 'Mental_disorders'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2021'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2021'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Mental_disorders'])

# 4. Définition des variables finales
Y = df['Mental_disorders']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Mental_disorders'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Nombre années de vie en bonne santé perdues à cause des troubles mentaux pour 100 000 habitants')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 187
#                             OLS Regression Results
# ...
# Dep. Variable:       Mental_disorders   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     18.15
# Date:                Fri, 12 Dec 2025   Prob (F-statistic):           3.25e-05
# Time:                        11:00:18   Log-Likelihood:                -1364.6
# No. Observations:                 187   AIC:                             2733.
# Df Residuals:                     185   BIC:                             2740.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1398.7653    163.199      8.571      0.000    1076.794    1720.736
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2024', 'Indicateur nutrition poids/taille'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2024'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2024'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Indicateur nutrition poids/taille'])

# 4. Définition des variables finales
Y = df['Surpoids enfants <5 ans']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Indicateur nutrition poids/taille'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Pourcentage des enfants de moins de 5 en situation de malnutrition extrême')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 117
#                                OLS Regression Results
# ...
# Dep. Variable:     Surpoids enfants <5 ans   R-squared:                       0.206
# Model:                                 OLS   Adj. R-squared:                  0.199
# Method:                      Least Squares   F-statistic:                     29.90
# Date:                     Fri, 12 Dec 2025   Prob (F-statistic):           2.69e-07
# Time:                             11:25:31   Log-Likelihood:                -306.22
# No. Observations:                      117   AIC:                             616.4
# Df Residuals:                          115   BIC:                             622.0
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2024', 'Retard croissance enfants'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2024'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2024'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Retard croissance enfants'])

# 4. Définition des variables finales
Y = df['Retard croissance enfants']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Retard croissance enfants'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Prévalence du retard de croissance chez les enfants de moins de 5 ans (%)')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 146
#                                 OLS Regression Results
# ...
# Dep. Variable:     Retard croissance enfants   R-squared:                       0.606
# Model:                                   OLS   Adj. R-squared:                  0.604
# Method:                        Least Squares   F-statistic:                     221.9
# Date:                       Fri, 12 Dec 2025   Prob (F-statistic):           5.83e-31
# Time:                               11:35:52   Log-Likelihood:                -505.78
# No. Observations:                        146   AIC:                             1016.
# Df Residuals:                            144   BIC:                             1022.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
# Si tes décimales sont des virgules, ajoute decimal=',' dans la parenthèse
df = pd.read_csv('Table_complète.csv') 

# --- A MODIFIER SELON TON FICHIER ---
nom_colonne_Y = 'Espérance de vie totale'
nom_colonne_D = '2022'             # Variable qui sera passée en log
nom_colonne_G = 'Dépenses publiques santé'   # TA 2ème VARIABLE (ex: 'Education', 'Chomage')
# ------------------------------------

# 2. Nettoyage et Conversion (Pour les 3 variables)
cols_to_check = [nom_colonne_Y, nom_colonne_D, nom_colonne_G]

# On force tout en numérique
for col in cols_to_check:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# On supprime les lignes vides (Si une seule des 3 valeurs manque, on supprime la ligne)
df = df.dropna(subset=cols_to_check)

# On filtre les valeurs <= 0 pour la variable qui va passer au Log (PIB)
df = df[df[nom_colonne_D] > 0]

# 3. Transformation des variables
df['log_PIB'] = np.log(df[nom_colonne_D]) # Ton D
# Si tu ne transformes pas G, on la garde telle quelle

# 4. Définition de Y et X (Multiple)
Y = df[nom_colonne_Y]

# C'est ICI que ça change : on sélectionne plusieurs colonnes avec des double crochets [[ ]]
X = df[['log_PIB', nom_colonne_G]] 

# 5. Ajout de la constante (le vecteur 1)
# X devient une matrice avec 3 colonnes : (1, log_PIB, G)
X_with_const = sm.add_constant(X)

# 6. Régression
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie totale   R-squared:                       0.690
# Model:                                 OLS   Adj. R-squared:                  0.687
# Method:                      Least Squares   F-statistic:                     192.9
# Date:                     Fri, 12 Dec 2025   Prob (F-statistic):           8.86e-45
# Time:                             11:44:56   Log-Likelihood:                -493.22
# No. Observations:                      176   AIC:                             992.4
# Df Residuals:                          173   BIC:                             1002.
# Df Model:                                2
# Covariance Type:                 nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
# Si tes décimales sont des virgules, ajoute decimal=',' dans la parenthèse
df = pd.read_csv('Table_complète.csv') 

# --- A MODIFIER SELON TON FICHIER ---
nom_colonne_Y = 'Espérance de vie totale'
nom_colonne_D = '2022'             # Variable qui sera passée en log
nom_colonne_G = 'Capacité réponse sanitaire'   # TA 2ème VARIABLE (ex: 'Education', 'Chomage')
# ------------------------------------

# 2. Nettoyage et Conversion (Pour les 3 variables)
cols_to_check = [nom_colonne_Y, nom_colonne_D, nom_colonne_G]

# On force tout en numérique
for col in cols_to_check:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# On supprime les lignes vides (Si une seule des 3 valeurs manque, on supprime la ligne)
df = df.dropna(subset=cols_to_check)

# On filtre les valeurs <= 0 pour la variable qui va passer au Log (PIB)
df = df[df[nom_colonne_D] > 0]

# 3. Transformation des variables
df['log_PIB'] = np.log(df[nom_colonne_D]) # Ton D
# Si tu ne transformes pas G, on la garde telle quelle

# 4. Définition de Y et X (Multiple)
Y = df[nom_colonne_Y]

# C'est ICI que ça change : on sélectionne plusieurs colonnes avec des double crochets [[ ]]
X = df[['log_PIB', nom_colonne_G]] 

# 5. Ajout de la constante (le vecteur 1)
# X devient une matrice avec 3 colonnes : (1, log_PIB, G)
X_with_const = sm.add_constant(X)

# 6. Régression
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie totale   R-squared:                       0.722
# Model:                                 OLS   Adj. R-squared:                  0.719
# Method:                      Least Squares   F-statistic:                     224.9
# Date:                     Fri, 12 Dec 2025   Prob (F-statistic):           7.51e-49
# Time:                             11:47:40   Log-Likelihood:                -483.57
# No. Observations:                      176   AIC:                             973.1
# Df Residuals:                          173   BIC:                             982.6
# Df Model:                                2
# Covariance Type:                 nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 1. Chargement
# Si tes décimales sont des virgules, ajoute decimal=',' dans la parenthèse
df = pd.read_csv('Table_complète.csv') 

# --- A MODIFIER SELON TON FICHIER ---
nom_colonne_Y = 'Espérance de vie totale'
nom_colonne_D = '2022'             # Variable qui sera passée en log
nom_colonne_G = 'Médecins pour 10k habitants'   # TA 2ème VARIABLE (ex: 'Education', 'Chomage')
# ------------------------------------

# 2. Nettoyage et Conversion (Pour les 3 variables)
cols_to_check = [nom_colonne_Y, nom_colonne_D, nom_colonne_G]

# On force tout en numérique
for col in cols_to_check:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# On supprime les lignes vides (Si une seule des 3 valeurs manque, on supprime la ligne)
df = df.dropna(subset=cols_to_check)

# On filtre les valeurs <= 0 pour la variable qui va passer au Log (PIB)
df = df[df[nom_colonne_D] > 0]

# 3. Transformation des variables
df['log_PIB'] = np.log(df[nom_colonne_D]) # Ton D
# Si tu ne transformes pas G, on la garde telle quelle

# 4. Définition de Y et X (Multiple)
Y = df[nom_colonne_Y]

# C'est ICI que ça change : on sélectionne plusieurs colonnes avec des double crochets [[ ]]
X = df[['log_PIB', nom_colonne_G]] 

# 5. Ajout de la constante (le vecteur 1)
# X devient une matrice avec 3 colonnes : (1, log_PIB, G)
X_with_const = sm.add_constant(X)

# 6. Régression
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie totale   R-squared:                       0.721
# Model:                                 OLS   Adj. R-squared:                  0.718
# Method:                      Least Squares   F-statistic:                     215.0
# Date:                     Fri, 12 Dec 2025   Prob (F-statistic):           8.50e-47
# Time:                             11:50:47   Log-Likelihood:                -463.18
# No. Observations:                      169   AIC:                             932.4
# Df Residuals:                          166   BIC:                             941.8
# Df Model:                                2
# Covariance Type:                 nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# --- 1. CONFIGURATION (C'est ici que tu modifies) ---
fichier_csv = 'Table_complète.csv'
decimal_separator = '.' # Mets ',' si ton fichier vient d'un Excel français

# Noms EXACTS de tes colonnes dans le CSV :
col_Y  = 'Espérance de vie totale'    # Variable expliquée
col_D  = '2022'              # Variable à passer en Log
col_X2 = 'Médecins pour 10k habitants'   # Ex: 'Education'
col_X3 = 'Capacité réponse sanitaire'   # Ex: 'Chomage'
col_X4 = 'Personnel infirmier densité'   # Ex: 'Depenses_Sante'

# Liste de toutes les colonnes nécessaires
all_cols = [col_Y, col_D, col_X2, col_X3, col_X4]

# --- 2. CHARGEMENT ET NETTOYAGE ---
df = pd.read_csv(fichier_csv, decimal=decimal_separator)

# Conversion forcée en numérique (traite les erreurs de texte)
for col in all_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Suppression des lignes vides (Si une seule valeur manque sur les 5, on supprime la ligne)
df = df.dropna(subset=all_cols)

# Filtre pour le Log (PIB doit être > 0)
df = df[df[col_D] > 0]

# --- 3. PRÉPARATION DU MODÈLE ---

# Transformation Logarithmique pour le PIB
df['log_PIB'] = np.log(df[col_D])

# Définition de Y
Y = df[col_Y]

# Définition de X (La liste contient maintenant 4 variables)
# On met 'log_PIB' + les 3 autres variables originales
X = df[['log_PIB', col_X2, col_X3, col_X4]]

# Ajout de la constante (pour l'ordonnée à l'origine)
X_with_const = sm.add_constant(X)

# --- 4. EXÉCUTION ---
print(f"Régression effectuée sur {len(df)} observations.")
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())
# Out:
# Régression effectuée sur 168 observations.
#                                OLS Regression Results
# ...
# Dep. Variable:     Espérance de vie totale   R-squared:                       0.748
# Model:                                 OLS   Adj. R-squared:                  0.742
# Method:                      Least Squares   F-statistic:                     121.2
# Date:                     Sat, 13 Dec 2025   Prob (F-statistic):           9.03e-48
# Time:                             14:25:23   Log-Likelihood:                -452.30
# No. Observations:                      168   AIC:                             914.6
# Df Residuals:                          163   BIC:                             930.2
# Df Model:                                4
# Covariance Type:                 nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# --- 1. CONFIGURATION (C'est ici que tu modifies) ---
fichier_csv = 'Table_complète.csv'
decimal_separator = '.' # Mets ',' si ton fichier vient d'un Excel français

# Noms EXACTS de tes colonnes dans le CSV :
col_Y  = 'Retard croissance enfants'    # Variable expliquée
col_D  = '2022'              # Variable à passer en Log
col_X2 = 'Médecins pour 10k habitants'   # Ex: 'Education'
col_X3 = 'Capacité réponse sanitaire'   # Ex: 'Chomage'
col_X4 = 'Dépenses publiques santé'   # Ex: 'Depenses_Sante'

# Liste de toutes les colonnes nécessaires
all_cols = [col_Y, col_D, col_X2, col_X3, col_X4]

# --- 2. CHARGEMENT ET NETTOYAGE ---
df = pd.read_csv(fichier_csv, decimal=decimal_separator)

# Conversion forcée en numérique (traite les erreurs de texte)
for col in all_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Suppression des lignes vides (Si une seule valeur manque sur les 5, on supprime la ligne)
df = df.dropna(subset=all_cols)

# Filtre pour le Log (PIB doit être > 0)
df = df[df[col_D] > 0]

# --- 3. PRÉPARATION DU MODÈLE ---

# Transformation Logarithmique pour le PIB
df['log_PIB'] = np.log(df[col_D])

# Définition de Y
Y = df[col_Y]

# Définition de X (La liste contient maintenant 4 variables)
# On met 'log_PIB' + les 3 autres variables originales
X = df[['log_PIB', col_X2, col_X3, col_X4]]

# Ajout de la constante (pour l'ordonnée à l'origine)
X_with_const = sm.add_constant(X)

# --- 4. EXÉCUTION ---
print(f"Régression effectuée sur {len(df)} observations.")
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())
# Out:
# Régression effectuée sur 148 observations.
#                                 OLS Regression Results
# ...
# Dep. Variable:     Retard croissance enfants   R-squared:                       0.587
# Model:                                   OLS   Adj. R-squared:                  0.576
# Method:                        Least Squares   F-statistic:                     50.84
# Date:                       Fri, 12 Dec 2025   Prob (F-statistic):           1.45e-26
# Time:                               11:59:48   Log-Likelihood:                -520.08
# No. Observations:                        148   AIC:                             1050.
# Df Residuals:                            143   BIC:                             1065.
# Df Model:                                  4
# Covariance Type:                   nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# --- 1. CONFIGURATION (C'est ici que tu modifies) ---
fichier_csv = 'Table_complète.csv'
decimal_separator = '.' # Mets ',' si ton fichier vient d'un Excel français

# Noms EXACTS de tes colonnes dans le CSV :
col_Y  = 'Taux mortalité brute'    # Variable expliquée
col_D  = '2022'              # Variable à passer en Log
col_X2 = 'Médecins pour 10k habitants'   # Ex: 'Education'
col_X3 = 'Capacité réponse sanitaire'   # Ex: 'Chomage'
col_X4 = 'Dépenses publiques santé'   # Ex: 'Depenses_Sante'

# Liste de toutes les colonnes nécessaires
all_cols = [col_Y, col_D, col_X2, col_X3, col_X4]

# --- 2. CHARGEMENT ET NETTOYAGE ---
df = pd.read_csv(fichier_csv, decimal=decimal_separator)

# Conversion forcée en numérique (traite les erreurs de texte)
for col in all_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Suppression des lignes vides (Si une seule valeur manque sur les 5, on supprime la ligne)
df = df.dropna(subset=all_cols)

# Filtre pour le Log (PIB doit être > 0)
df = df[df[col_D] > 0]

# --- 3. PRÉPARATION DU MODÈLE ---

# Transformation Logarithmique pour le PIB
df['log_PIB'] = np.log(df[col_D])

# Définition de Y
Y = df[col_Y]

# Définition de X (La liste contient maintenant 4 variables)
# On met 'log_PIB' + les 3 autres variables originales
X = df[['log_PIB', col_X2, col_X3, col_X4]]

# Ajout de la constante (pour l'ordonnée à l'origine)
X_with_const = sm.add_constant(X)

# --- 4. EXÉCUTION ---
print(f"Régression effectuée sur {len(df)} observations.")
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())
# Out:
# Régression effectuée sur 177 observations.
#                              OLS Regression Results
# ...
# Dep. Variable:     Taux mortalité brute   R-squared:                       0.697
# Model:                              OLS   Adj. R-squared:                  0.690
# Method:                   Least Squares   F-statistic:                     98.76
# Date:                  Fri, 12 Dec 2025   Prob (F-statistic):           1.70e-43
# Time:                          12:00:58   Log-Likelihood:                -545.76
# No. Observations:                   177   AIC:                             1102.
# Df Residuals:                       172   BIC:                             1117.
# Df Model:                             4
# Covariance Type:              nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2023', 'Personnel infirmier densité'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2023'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2023'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Personnel infirmier densité'])

# 4. Définition des variables finales
Y = df['Personnel infirmier densité']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit()

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Personnel infirmier densité'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Densité de personnel infirmier pour 10k habitants')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 182
#                                  OLS Regression Results
# ...
# Dep. Variable:     Personnel infirmier densité   R-squared:                       0.623
# Model:                                     OLS   Adj. R-squared:                  0.621
# Method:                          Least Squares   F-statistic:                     297.2
# Date:                         Sat, 13 Dec 2025   Prob (F-statistic):           5.85e-40
# Time:                                 14:22:18   Log-Likelihood:                -833.13
# No. Observations:                          182   AIC:                             1670.
# Df Residuals:                              180   BIC:                             1677.
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# ==========================================
# 1. ZONE DE CONFIGURATION 
# ==========================================

# Chemin vers ton fichier CSV
fichier_csv = 'Table_complète.csv'

# Nom exact de la colonne Y (celle qu'on va passer au logarithme)
colonne_Y = '2024'  # Exemple : remplace par ton vrai nom de colonne

# Liste des 7 noms exacts de tes colonnes explicatives (X)
# L'ordre ici correspondra à tes variables (D, G, E, F, H, I, J) dans l'équation
colonnes_X = [
    'Personnel infirmier densité',          # Correspondra à D
    'Médecins pour 10k habitants',  # Correspondra à G
    'Capacité réponse sanitaire',     # Correspondra à E
    'Dépenses publiques santé',  # Correspondra à F
    'Accès eau potable sûre',        # Correspondra à H
    "Niveau d'assainissement",  # Correspondra à I
    'Déchets domestiques traités'   # Correspondra à J
]

# ==========================================
# 2. CHARGEMENT ET NETTOYAGE ROBUSTE
# ==========================================

# Astuce : si ton CSV utilise des virgules pour les décimales (format français "12,5"),
# ajoute decimal=',' dans read_csv. Sinon, garde le par défaut.
try:
    df = pd.read_csv(fichier_csv) # Ajoute decimal=',' si nécessaire
except FileNotFoundError:
    print(f"ERREUR : Le fichier '{fichier_csv}' est introuvable.")
    exit()

# Liste de toutes les colonnes utiles (Y + les X)
cols_utiles = [colonne_Y] + colonnes_X

# VÉRIFICATION DE L'EXISTENCE DES COLONNES
missing = [c for c in cols_utiles if c not in df.columns]
if missing:
    print(f"ERREUR: Colonnes introuvables : {missing}")
    exit()

print(f"Données initiales : {len(df)} lignes.")

# A. FORCER LE FORMAT NUMÉRIQUE
# Cela transforme les textes bizarres (ex: "Erreur", " ", "N/A") en NaN (vide)
for col in cols_utiles:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# B. RETIRER LES VALEURS INFINIES ET VIDES
# On remplace les infinis par des NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# On compte combien de lignes sont vides avant de supprimer
n_avant = len(df)
df = df.dropna(subset=cols_utiles)
n_apres = len(df)
n_suppr = n_avant - n_apres

if n_suppr > 0:
    print(f"ATTENTION : {n_suppr} lignes contenaient des erreurs ou vides et ont été supprimées.")
    print(f"Lignes restantes pour l'analyse : {n_apres}")
else:
    print("Aucune ligne vide détectée. Données propres.")

if len(df) == 0:
    print("ERREUR CRITIQUE : Toutes les lignes ont été supprimées ! Vérifie le format de ton CSV.")
    exit()

# ==========================================
# 3. PRÉPARATION MATHÉMATIQUE
# ==========================================

# Application du Logarithme sur Y (uniquement sur valeurs > 0)
df = df[df[colonne_Y] > 0] # Sécurité supplémentaire pour le log
y_log = np.log(df[colonne_Y])

# Sélection des variables X
X = df[colonnes_X]

# Ajout de la constante
X = sm.add_constant(X)

# ==========================================
# 3. TRAITEMENT MATHÉMATIQUE
# ==========================================

# Application du Logarithme sur Y
# On filtre les valeurs <= 0 pour éviter les erreurs mathématiques
df_clean = df[df[colonne_Y] > 0].copy()
y_log = np.log(df_clean[colonne_Y])

# Sélection des variables X
X = df_clean[colonnes_X]

# Ajout de la constante (Variable "1") pour l'intercepte (le coefficient 'a')
X = sm.add_constant(X)

# ==========================================
# 4. RÉGRESSION (OLS) ET RÉSULTATS
# ==========================================

model = sm.OLS(y_log, X)
results = model.fit()

print("\n" + "="*50)
print("RÉSULTATS DE LA RÉGRESSION : log(Y) = a*1 + b*D + ...")
print("="*50)
print(results.summary())

# Affichage clair de l'équation finale
coeffs = results.params

print("\n--- ÉQUATION PRÉDICTIVE ESTIMÉE ---")
print("log(Y) = ")
print(f"   {coeffs['const']:.5f} (Constante a)")

# On boucle pour afficher chaque variable avec son coefficient
mapping_lettres = ['b', 'c', 'd', 'e', 'h', 'i', 'j'] # Tes lettres mathématiques

for i, nom_col in enumerate(colonnes_X):
    coef_val = coeffs[nom_col]
    lettre = mapping_lettres[i] if i < len(mapping_lettres) else '?'
    signe = "+" if coef_val >= 0 else "" # Pour l'affichage joli
    print(f" {signe} {coef_val:.5f} * {nom_col} \t(coeff {lettre})")

# ==========================================
# 5. GRAPHIQUE (Réel vs Prédit)
# ==========================================
plt.figure(figsize=(10, 6))
pred_log = results.predict(X)
plt.scatter(y_log, pred_log, alpha=0.6, edgecolors='w')
plt.plot([y_log.min(), y_log.max()], [y_log.min(), y_log.max()], 'r--', lw=2)
plt.xlabel(f"log({colonne_Y}) Réel")
plt.ylabel(f"log({colonne_Y}) Prédit")
plt.title("Qualité de la prédiction")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Données initiales : 206 lignes.
# ATTENTION : 120 lignes contenaient des erreurs ou vides et ont été supprimées.
# Lignes restantes pour l'analyse : 86
#
# ...
# RÉSULTATS DE LA RÉGRESSION : log(Y) = a*1 + b*D + ...
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:                   2024   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     94.71
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           1.80e-35
# Time:                        16:47:32   Log-Likelihood:                -61.535
# No. Observations:                  86   AIC:                             139.1
# Df Residuals:                      78   BIC:                             158.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ...

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# ==========================================
# 1. ZONE DE CONFIGURATION (MODIFIÉE POUR 3 VARIABLES)
# ==========================================

fichier_csv = 'Table_complète.csv'  # Remplace par ton fichier
colonne_Y = '2023'            # Remplace par ta colonne Y

# On ne garde que 3 colonnes ici pour faire X = (1, D, G, H)
# Remplace les noms ci-dessous par les vrais noms de tes colonnes dans le CSV
colonnes_X = [
    'Personnel infirmier densité',          # Correspondra à la variable D
    'Dépenses publiques santé',  # Correspondra à la variable G
    'Capacité réponse sanitaire'         # Correspondra à la variable H
]

# ==========================================
# 2. CHARGEMENT ET NETTOYAGE (Le bloc robuste)
# ==========================================
try:
    df = pd.read_csv(fichier_csv) # Ajoute decimal=',' si ton Excel est en français
except FileNotFoundError:
    print(f"ERREUR : Le fichier '{fichier_csv}' est introuvable.")
    exit()

cols_utiles = [colonne_Y] + colonnes_X

# Vérification présence colonnes
missing = [c for c in cols_utiles if c not in df.columns]
if missing:
    print(f"ERREUR: Colonnes introuvables dans le CSV : {missing}")
    exit()

# Conversion numérique et nettoyage des infinis/NaN
for col in cols_utiles:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=cols_utiles)

if len(df) == 0:
    print("ERREUR : Plus aucune donnée après nettoyage.")
    exit()

# ==========================================
# 3. PRÉPARATION ET RÉGRESSION
# ==========================================

# Logarithme sur Y
df = df[df[colonne_Y] > 0]
y_log = np.log(df[colonne_Y])

# Sélection des variables X (D, G, H)
X = df[colonnes_X]

# Ajout de la constante (le "1")
X = sm.add_constant(X)

# Création du modèle
model = sm.OLS(y_log, X)
results = model.fit()

# ==========================================
# 4. RÉSULTATS
# ==========================================
print("\n" + "="*50)
print("RÉSULTATS (Modèle réduit : D, G, H)")
print("="*50)
print(results.summary())

coeffs = results.params
print("\n--- ÉQUATION ESTIMÉE ---")
print("log(Y) = ")
print(f"   {coeffs['const']:.4f} (Constante a)")

# Affichage dynamique des 3 variables
lettres = ['b', 'c', 'h'] # Correspondant à D, G, H
for i, nom_col in enumerate(colonnes_X):
    val = coeffs[nom_col]
    signe = "+" if val >= 0 else ""
    lettre = lettres[i] if i < len(lettres) else '?'
    print(f" {signe} {val:.4f} * {nom_col} \t(coeff {lettre})")

# ==========================================
# 5. VISUALISATION SIMPLE
# ==========================================
plt.figure(figsize=(8, 5))
ypred = results.predict(X)
plt.scatter(y_log, ypred, alpha=0.5)
plt.plot([y_log.min(), y_log.max()], [y_log.min(), y_log.max()], 'r--')
plt.xlabel("log(Y) Réel")
plt.ylabel("log(Y) Prédit")
plt.title("Régression avec D, G, H")
plt.show()
# Out:
# ...
# RÉSULTATS (Modèle réduit : D, G, H)
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:                   2023   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     147.4
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           8.71e-48
# Time:                        17:34:40   Log-Likelihood:                -204.69
# No. Observations:                 180   AIC:                             417.4
# Df Residuals:                     176   BIC:                             430.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...
