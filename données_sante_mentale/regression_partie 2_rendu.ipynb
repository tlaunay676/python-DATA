# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2021', 'Eating_disorders'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2021'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2021'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Eating_disorders'])

# 4. Définition des variables finales
Y = df['Eating_disorders']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit(cov_type='HC1')

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Eating_disorders'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Nombre années de vie en bonne santé perdues à cause de troubles de la santé pour 100 000 habitants')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 187
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Eating_disorders   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.687
# Method:                 Least Squares   F-statistic:                     293.9
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           4.61e-40
# Time:                        17:52:22   Log-Likelihood:                -812.53
# No. Observations:                 187   AIC:                             1629.
# Df Residuals:                     185   BIC:                             1636.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -111.9486      9.270    -12.076      0.000    -130.118     -93.779
# log_PIB       19.3145      1.127     17.143      0.000      17.106      21.523
# ==============================================================================
# Omnibus:                       64.998   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              356.660
# Skew:                           1.178   Prob(JB):                     3.57e-78
# Kurtosis:                       9.342   Cond. No.                         56.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2021', 'Taux de suicides'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2021'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2021'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Taux de suicides'])

# 4. Définition des variables finales
Y = df['Taux de suicides']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit(cov_type='HC1')

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Taux de suicides'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Taux de suicide')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 178
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Taux de suicides   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     13.34
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           0.000342
# Time:                        17:52:15   Log-Likelihood:                -568.58
# No. Observations:                 178   AIC:                             1141.
# Df Residuals:                     176   BIC:                             1148.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2911      2.250      0.129      0.897      -4.119       4.701
# log_PIB        0.9458      0.259      3.652      0.000       0.438       1.453
# ==============================================================================
# Omnibus:                       33.413   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.676
# Skew:                           1.093   Prob(JB):                     7.32e-11
# Kurtosis:                       4.229   Cond. No.                         55.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2021', 'Mental_disorders'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2021'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2021'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Mental_disorders'])

# 4. Définition des variables finales
Y = df['Mental_disorders']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit(cov_type='HC1')

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Mental_disorders'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Nombre années de vie en bonne santé perdues à cause des troubles mentaux pour 100 000 habitants')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 187
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Mental_disorders   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     17.64
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           4.14e-05
# Time:                        17:52:07   Log-Likelihood:                -1364.6
# No. Observations:                 187   AIC:                             2733.
# Df Residuals:                     185   BIC:                             2740.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1398.7653    161.627      8.654      0.000    1081.983    1715.548
# log_PIB       77.9861     18.566      4.200      0.000      41.597     114.375
# ==============================================================================
# Omnibus:                        2.282   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                2.010
# Skew:                           0.250   Prob(JB):                        0.366
# Kurtosis:                       3.086   Cond. No.                         56.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 1. Chargement
df = pd.read_csv('Table_complète.csv')

# --- ETAPE DE NETTOYAGE CRITIQUE ---

# A. On supprime les lignes vides dès le départ (NaN)
# Si une ligne n'a pas de PIB ou pas d'espérance de vie, on l'enlève
df = df.dropna(subset=['2024', 'Surpoids enfants <5 ans'])

# B. On ne garde que les PIB strictement positifs
# C'est OBLIGATOIRE pour le logarithme. log(0) = infini (erreur)
df = df[df['2024'] > 0]

# --- FIN DU NETTOYAGE ---

# 2. Création du Log
df['log_PIB'] = np.log(df['2024'])

# 3. Vérification ultime (au cas où des infinis traînent encore)
# On remplace les infinis par NaN et on les supprime
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna(subset=['log_PIB', 'Surpoids enfants <5 ans'])

# 4. Définition des variables finales
Y = df['Surpoids enfants <5 ans']
X = df['log_PIB']

print(f"Nombre de lignes utilisées pour la régression : {len(df)}")

# 5. Régression
X_with_const = sm.add_constant(X)
modele = sm.OLS(Y, X_with_const)
resultats = modele.fit(cov_type='HC1')

print(resultats.summary())

# --- 5. GRAPHIQUE (Optionnel pour vérifier visuellement) ---
plt.scatter(df['log_PIB'], df['Surpoids enfants <5 ans'], alpha=0.5, label='Données')
plt.plot(df['log_PIB'], resultats.predict(), color='red', label='Régression')
plt.xlabel('Log(PIB)')
plt.ylabel('Pourcentage des enfants de moins de 5 en surpoids')
plt.legend()
plt.show()
# Out:
# Nombre de lignes utilisées pour la régression : 147
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Surpoids enfants <5 ans   R-squared:                       0.191
# Model:                                 OLS   Adj. R-squared:                  0.185
# Method:                      Least Squares   F-statistic:                     33.23
# Date:                     Tue, 16 Dec 2025   Prob (F-statistic):           4.74e-08
# Time:                             17:52:02   Log-Likelihood:                -405.01
# No. Observations:                      147   AIC:                             814.0
# Df Residuals:                          145   BIC:                             820.0
# Df Model:                                1
# Covariance Type:                       HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -5.1823      1.988     -2.606      0.009      -9.079      -1.285
# log_PIB        1.3899      0.241      5.765      0.000       0.917       1.863
# ==============================================================================
# Omnibus:                       37.545   Durbin-Watson:                   1.540
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.241
# Skew:                           1.205   Prob(JB):                     4.13e-15
# Kurtosis:                       5.238   Cond. No.                         58.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
