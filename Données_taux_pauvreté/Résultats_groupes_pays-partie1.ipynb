# %%
==================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Espérance de vie totale'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Espérance de vie moyenne (années)'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement deimport pandas as pd
import matplotlib.pyplot as plt
import sys

# ========s données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Espérance de vie totale' par groupe...
#
# Résultats :
# IncomeGroup
# Low income             62.500000
# Lower middle income    67.018367
# Upper middle income    71.618000
# High income            78.418966
# Name: Espérance de vie totale, dtype: float64
# --> Affichage du graphique.

# %%
==================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Espérance de vie totale'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Espérance de vie moyenne (années)'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement deimport pandas as pd
import matplotlib.pyplot as plt
import sys

# ========s données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Espérance de vie en bonne santé totale' par groupe...
#
# Résultats :
# IncomeGroup
# Low income             54.320000
# Lower middle income    58.424490
# Upper middle income    62.384000
# High income            67.658621
# Name: Espérance de vie en bonne santé totale, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Taux mortalité brute'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Taux de mortalité néonatale (pour 1000 naissances)'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Taux mortalité brute' par groupe...
#
# Résultats :
# IncomeGroup
# High income             3.519048
# Upper middle income     9.224528
# Lower middle income    18.008163
# Low income             25.268000
# Name: Taux mortalité brute, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Taux de mortalité maternelle'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Taux de mortalité maternelle (pour 1000 naissances)'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Taux de mortalité maternelle' par groupe...
#
# Résultats :
# IncomeGroup
# High income             19.156250
# Upper middle income     58.075472
# Lower middle income    181.938776
# Low income             363.480000
# Name: Taux de mortalité maternelle, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Retard croissance enfants'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Prévalence du retard de croissance chez les enfants de moins de 5 ans (%)'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Retard croissance enfants' par groupe...
#
# Résultats :
# IncomeGroup
# High income             5.116667
# Upper middle income    10.280000
# Lower middle income    22.414894
# Low income             32.276000
# Name: Retard croissance enfants, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Médecins pour 10k habitants'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Nombre de médecins pour 10k habitants'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Médecins pour 10k habitants' par groupe...
#
# Résultats :
# IncomeGroup
# Low income             0.677500
# Lower middle income    1.273043
# Upper middle income    3.727800
# High income            7.087258
# Name: Médecins pour 10k habitants, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Capacité réponse sanitaire'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Moyenne des 15 scores relatifs aux capacités fondamentales du Règlement sanitaire international'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Capacité réponse sanitaire' par groupe...
#
# Résultats :
# IncomeGroup
# Low income             45.760000
# Lower middle income    55.591837
# Upper middle income    64.134615
# High income            76.444444
# Name: Capacité réponse sanitaire, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Dépenses publiques santé'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Part des dépenses de santé dans les dépenses publiques(%)'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Dépenses publiques santé' par groupe...
#
# Résultats :
# IncomeGroup
# Low income              5.329583
# Lower middle income     7.555102
# Upper middle income    11.767500
# High income            14.862540
# Name: Dépenses publiques santé, dtype: float64
# --> Affichage du graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# ==========================================
#               CONFIGURATION
# ==========================================

# Le nom de ton fichier (doit être dans le même dossier)
FICHIER_CSV = 'Table_groupes_pays_richesse.csv'

# Argument 1 : La colonne pour faire les groupes (ex: Pays riches, pauvres...)
COLONNE_GROUPE = 'IncomeGroup'

# Argument 2 : La colonne dont on veut la moyenne
COLONNE_VALEUR = 'Personnel infirmier densité'

# Le titre de l'axe vertical (Y)
TITRE_AXE_Y = 'Densité de personnel infirmier pour 10k habitants'

# ==========================================

def main():
    print("--- Démarrage du programme ---")

    # 1. Chargement des données
    try:
        # On essaie de lire le CSV. 
        # Si ton fichier CSV sépare les colonnes par des points-virgules, remplace sep=',' par sep=';'
        df = pd.read_csv(FICHIER_CSV, sep=',') 
        print(f"--> Fichier '{FICHIER_CSV}' chargé avec succès ({len(df)} lignes).")
    except FileNotFoundError:
        print(f"ERREUR : Le fichier '{FICHIER_CSV}' est introuvable.")
        print("Vérifie que le fichier est bien dans le même dossier que ce script Python.")
        sys.exit(1)

    # 2. Vérification que les colonnes existent
    # On nettoie les espaces potentiels dans les noms de colonnes du fichier pour éviter des erreurs bêtes
    df.columns = df.columns.str.strip() 
    
    if COLONNE_GROUPE not in df.columns or COLONNE_VALEUR not in df.columns:
        print(f"ERREUR : Une des colonnes demandées n'existe pas dans le fichier.")
        print(f"Tu as demandé : '{COLONNE_GROUPE}' et '{COLONNE_VALEUR}'")
        print(f"Colonnes trouvées dans le fichier : {list(df.columns)}")
        sys.exit(1)

    # 3. Nettoyage et Calculs
    print("--> Nettoyage des données...")
    
    # On retire les lignes où la colonne de groupe est vide
    df_clean = df.dropna(subset=[COLONNE_GROUPE]).copy()
    
    # On convertit la colonne valeur en nombres (au cas où il y ait du texte qui gêne)
    df_clean[COLONNE_VALEUR] = pd.to_numeric(df_clean[COLONNE_VALEUR], errors='coerce')
    
    # Groupement et calcul de la moyenne
    print(f"--> Calcul de la moyenne de '{COLONNE_VALEUR}' par groupe...")
    resultat = df_clean.groupby(COLONNE_GROUPE)[COLONNE_VALEUR].mean().sort_values()

    print("\nRésultats :")
    print(resultat)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Création des bâtons
    plt.bar(resultat.index, resultat.values, color='#4c72b0', edgecolor='black')

    # Mises en forme
    plt.xlabel(COLONNE_GROUPE, fontsize=12, fontweight='bold')
    plt.ylabel(TITRE_AXE_Y, fontsize=12, fontweight='bold')
    plt.title(f"Graphique : {TITRE_AXE_Y} selon le niveau de richesse", fontsize=14)
    
    # Rotation des étiquettes en bas pour qu'elles soient lisibles
    plt.xticks(rotation=45, ha='right')
    
    # Grille
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    print("--> Affichage du graphique.")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Démarrage du programme ---
# --> Fichier 'Table_groupes_pays_richesse.csv' chargé avec succès (277 lignes).
# --> Nettoyage des données...
# --> Calcul de la moyenne de 'Personnel infirmier densité' par groupe...
#
# Résultats :
# IncomeGroup
# Low income             10.339583
# Lower middle income    21.494490
# Upper middle income    43.536604
# High income            83.524355
# Name: Personnel infirmier densité, dtype: float64
# --> Affichage du graphique.
